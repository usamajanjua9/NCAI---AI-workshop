# %% [markdown]
# ---
#
# # 🚚 **WEEK 11 – DAY 2: AI-Powered Warehouse Optimization & Logistics Automation**
#
# ## 🔹 **Theory Topics**
#
# ---
#
# ## 📦 **1. What is Warehouse Optimization?**
#
# ### 📖 **Definition**
#
# Warehouse Optimization is the process of designing and managing warehouse operations in the **most efficient and cost-effective way**, while still ensuring speed, accuracy, and flexibility.
# It covers everything from how goods are stored and retrieved, to how robots or workers move through the facility.
#
# ---
#
# ### 🎯 **Goals of Warehouse Optimization**
#
# 1. **Better Space Utilization**
#
#    * Maximize use of available floor and vertical space.
#    * Reduce wasted aisles and unorganized shelves.
#
# 2. **Faster Picking Speed**
#
#    * Improve how quickly items can be located, picked, and packed.
#    * Use intelligent slotting (placing fast-moving items closer).
#
# 3. **Optimal Shelf Allocation**
#
#    * Assign shelves based on product demand frequency.
#    * Keep heavy or bulky items in easy-to-reach spots.
#
# 4. **Lower Operational Costs**
#
#    * Reduce unnecessary worker travel time.
#    * Cut down on handling and storage costs.
#
# 5. **Error Reduction & Safety**
#
#    * Minimize picking errors.
#    * Reduce workplace hazards by better planning of traffic flow.
#
# ---
#
# ## ⚠️ **2. Common Bottlenecks in Traditional Warehouses**
#
# Despite being the backbone of supply chains, traditional warehouses face several **bottlenecks (slowdowns/inefficiencies)**:
#
# 1. **Poor Layout & Space Wastage**
#
#    * Shelves not arranged based on demand patterns.
#    * Empty spaces in racks or cluttered aisles.
#
# 2. **Slow Picking Process**
#
#    * Workers spend too much time walking between shelves.
#    * Lack of intelligent product placement.
#
# 3. **Inventory Inaccuracy**
#
#    * Manual entry errors leading to stockouts or overstocking.
#    * Mismatch between physical stock and system records.
#
# 4. **Limited Visibility**
#
#    * No real-time tracking of goods.
#    * Managers lack live insights on stock levels and bottlenecks.
#
# 5. **High Labor Dependency**
#
#    * Processes rely heavily on manual work → prone to fatigue, mistakes, and high costs.
#
# 6. **Poor Order Fulfillment Speed**
#
#    * Difficulty in keeping up with **e-commerce demand** (like same-day or next-day delivery).
#
# ---
#
# ✅ Example: A local **grocery chain warehouse** may store sugar, rice, and oil randomly across faraway shelves. Workers walk extra distances to collect them for each order, slowing down fulfillment and raising costs. Optimized placement could drastically cut travel time.
#
# ---

# %% [markdown]
# ---
#
# # 🤖 **AI in Warehouse Management**
#
# AI transforms warehouses from being **reactive storage centers** into **smart, predictive, and automated ecosystems**. Instead of waiting for demand to happen, AI helps warehouses *anticipate, plan, and act* in real-time.
#
# ---
#
# ## 🛣️ **1. Role of AI in Route Planning, Shelf Allocation & Demand-Based Stocking**
#
# * **Route Planning**
#   AI systems calculate the **shortest, least-congested routes** for workers or robots.
#
#   * Example: A picker needs 10 items → AI arranges the route to minimize walking distance.
#   * Algorithms like **Dijkstra’s shortest path** or reinforcement learning can power this.
#
# * **Shelf Allocation (Slotting Optimization)**
#   AI decides where each product should be placed for fastest access.
#
#   * **Fast-moving items** (e.g., milk, bread in a grocery warehouse) are placed near dispatch zones.
#   * **Seasonal items** (e.g., fans in summer, heaters in winter) are rotated closer when needed.
#
# * **Demand-Based Stocking**
#   AI predicts demand surges using historical data + trends.
#
#   * Example: Eid, Black Friday, or Ramadan → AI increases stock of high-demand items.
#   * Prevents both *overstocking* and *stockouts*.
#
# ---
#
# ## 🧩 **2. Clustering Algorithms for Zone Picking**
#
# * **Problem**: Workers waste time zig-zagging across the warehouse.
# * **AI Solution**: Use **clustering algorithms (like K-Means)** to group items into *zones*.
#
#   * Zone Picking = Each worker/robot is responsible for a **specific area/cluster**.
#   * Example:
#
#     * Worker A handles **Zone 1 (drinks, snacks)**
#     * Worker B handles **Zone 2 (stationery, electronics)**
#
# This reduces congestion and increases picking speed.
#
# ---
#
# ## ⚡ **3. Real-Time Inventory Decision-Making**
#
# * AI integrates with **IoT sensors, RFID tags, and ERP systems** to provide *live updates*.
# * Instead of monthly audits, managers see:
#
#   * 📉 *Low-stock alerts* (trigger automatic reorders).
#   * 📦 *Overstock alerts* (suggest discounts/promotions).
#   * 🕒 *Dynamic reallocation* (if product A isn’t selling, move it further back, bring fast-selling B forward).
#
# ---
#
# ## 👀 **4. Computer Vision for Inventory Tracking**
#
# AI doesn’t just rely on humans scanning barcodes — it **sees** the warehouse.
#
# * **Barcode and QR Scanning Automation**
#   Handheld or mounted scanners automatically update stock when items move.
#
# * **Object Detection with Cameras**
#   Cameras + AI (like **YOLOv8, OpenCV**) detect products, boxes, or even misplaced pallets in real-time.
#
#   * Example: A camera above a shelf can alert if a box is missing or wrongly placed.
#   * Reduces dependency on manual checks.
#
# ---
#
# ## 🚁 **5. Drones & Robots in Warehouses**
#
# * **Drones** fly across racks to scan inventory faster than humans.
# * **Autonomous Mobile Robots (AMRs)** carry goods to packing stations.
#
#   * Example: **Amazon’s Kiva robots** reduce walking distance for workers by 70–80%.
#
# These AI-powered machines boost speed, accuracy, and safety while lowering labor costs.
#
# ---
#
# ✅ *Bottom line*: AI makes warehouses **predictive, efficient, and automated** — a shift from *manual chaos* to *smart orchestration*.
#
# ---

# %% [markdown]
# ---
#
# # 🌐 **AI + IoT in Logistics**
#
# The combination of **Artificial Intelligence (AI)** and **Internet of Things (IoT)** is revolutionizing how goods are tracked, transported, and delivered. Together, they make logistics **real-time, adaptive, and reliable**.
#
# ---
#
# ## 📡 **1. Real-Time Tracking of Goods via RFID/IoT**
#
# * **RFID Tags & IoT Sensors**
#   Every box or pallet can have a tag/sensor that sends data continuously.
#
#   * Location → Where exactly is the truck/pallet now?
#   * Condition → Is the product being stored correctly (fragile, upright, sealed)?
#
# * **AI Integration**
#   AI dashboards process this live data to:
#
#   * Alert managers when goods are delayed or diverted.
#   * Automatically update customers about estimated delivery time.
#
# ✅ Example: *Courier services like TCS/DHL use RFID + GPS IoT sensors for live parcel tracking.*
#
# ---
#
# ## 🛣️ **2. Predictive Route Planning (Traffic + Weather Aware)**
#
# * **Problem**: Traditional route planning only considers distance.
#
# * **AI + IoT Solution**:
#
#   * IoT devices on trucks → collect live road data (speed, traffic jams, accidents).
#   * AI models → predict **best alternate routes**.
#   * Weather APIs → suggest avoiding flood-prone areas or icy roads.
#
# * **Benefit**: Reduces delays, fuel cost, and ensures on-time delivery.
#
# ✅ Example: *Foodpanda or Careem Delivery uses AI-based algorithms to reroute riders dynamically during traffic congestion.*
#
# ---
#
# ## ❄️ **3. Cold Chain Logistics with Temperature Sensors**
#
# * **Cold Chain = Transport of perishable goods** (meat, dairy, vaccines, medicines).
#
# * **IoT Sensors** constantly monitor:
#
#   * Temperature 🌡️
#   * Humidity 💧
#   * Door opening/closing events 🚪
#
# * **AI Systems** analyze this sensor data to:
#
#   * Trigger alerts if temperature goes above threshold (e.g., milk shipment warming up).
#   * Suggest preventive actions (reroute to nearest cold storage).
#   * Predict risks in advance (e.g., power failure at cold depot).
#
# ✅ Example: *Pfizer vaccine distribution relied on IoT temperature sensors + AI dashboards to maintain ultra-cold storage during COVID-19 supply chains.*
#
# ---
#
# 🔑 **In summary:**
# AI + IoT in logistics means **no blind spots**. Managers know **where the goods are, how they are doing, and the best way to deliver them safely**.
#
# ---

# %% [markdown]
# ---
#
# # ⚙️ **Logistics Automation in Action**
#
# ---
#
# ## 🚐 **1. Self-Routing Delivery Vans & Drones**
#
# * **Self-Routing Vans**
#   AI-powered vans can plan their own delivery routes using GPS + predictive algorithms.
#
#   * **Amazon** uses AI logistics systems to decide which warehouse sends the product and which route the van should take.
#   * Vans adapt to road closures, traffic jams, or weather in real time.
#
# * **Drones**
#   Drones are being tested for **last-mile delivery**.
#
#   * Example: **Amazon Prime Air** → small drones delivering within 30 minutes.
#   * **Zipline (Africa)** → drones deliver blood and medicine to rural hospitals.
#   * Pakistani logistics (like TCS or Bykea) have shown interest, but regulatory barriers exist.
#
# ---
#
# ## 📊 **2. Real-Time Dashboarding for Shipment Tracking**
#
# * **IoT + AI dashboards** show managers:
#
#   * Which trucks are on schedule
#   * Which shipments are delayed
#   * Estimated arrival times for every customer
#
# * Customers also benefit: they see live parcel movement (like **TCS, Leopards, DHL apps**).
#
# ✅ Example: *Foodpanda riders’ live tracking is a smaller version of this idea.*
#
# ---
#
# ## ⛽ **3. Role of AI in Reducing Delays & Fuel Usage**
#
# * AI analyzes road data, weather, and demand patterns to:
#
#   * Suggest **optimal delivery windows** (avoid rush hours).
#   * Group deliveries efficiently (cluster nearby addresses).
#   * Predict fuel consumption per route → pick the lowest-cost option.
#
# ⚡ Impact: Lower logistics costs, fewer emissions, faster deliveries.
#
# ---
#
# # 🇵🇰 **Challenges in Pakistani Context**
#
# 1. **🚧 Infrastructure Gaps**
#
#    * Poor road conditions, missing street signs, and frequent traffic jams limit the efficiency of AI-routing systems.
#    * Lack of widespread IoT infrastructure (e.g., sensors, RFID readers).
#
# 2. **💰 High Cost of AI Integration for SMEs**
#
#    * Large firms (Daraz, TCS, DHL) can afford AI + IoT.
#    * Small kiryana stores or SMEs find hardware (IoT sensors, drones, GPS) too expensive.
#
# 3. **🌐 Localization & Training of Models**
#
#    * AI models trained on Western addresses struggle with **Pakistani addressing systems** (e.g., “Gali #5, Near Chowk”).
#    * Urdu/roman Urdu labels on packages are often misread by OCR systems.
#    * Requires **localized AI models** trained on Urdu + regional languages.
#
# ---
#
# ✅ **Key Insight:** While Amazon and global giants showcase futuristic logistics automation, Pakistan must solve local barriers first — affordable IoT devices, better road networks, and AI models that understand our unique addressing/language systems.
#
# ---

# %% [markdown]
# ---
#
# # 🚚 AI-Powered Warehouse Optimization & Logistics Automation
#
# ### Week 11 – Day 2 Lab: Explained Simply for Everyone 🧑‍🏫
#
# ---
#
# ## 🔢 What is this lab about?
#
# Imagine you're running a **warehouse or delivery company** like Amazon or Daraz. Every day, you must:
#
# 1. **Deliver packages** to customers (but you want the shortest route!).
# 2. **Organize shelf space** so products are placed in smart spots.
# 3. **Track your stock** to know what's running out and what’s full.
#
# This lab shows how **Artificial Intelligence (AI)** can help do all that!
#
# ---
#
# ## 🧭 PART 1: Route Optimization (Delivery Route Problem)
#
# ### 🧩 Problem:
#
# You have one warehouse and multiple delivery locations. You want to **visit every customer** and come back - but with **minimum travel distance** (save fuel, save time!).
#
# ### 🧠 How AI helps:
#
# We use a simple AI technique called **Greedy Algorithm**. It works like this:
#
# * Start at the warehouse.
# * Find the **closest customer**.
# * Go there.
# * From there, find the next closest one...
# * Keep repeating until all are visited.
# * Come back to warehouse.
#
# 📌 This mimics how a human would do it if they just kept choosing the "next nearest" place.
#
# ### 📊 What we see:
#
# * A **list** showing the optimized delivery route (e.g., Warehouse → A → B → C → D → back to Warehouse).
# * A **map with dots and arrows** showing how the route looks on a graph.
#
# ---
#
# ## 📊 PART 2: Shelf Space Allocation (Organizing Products Smartly)
#
# ### 🧩 Problem:
#
# You have many products, but limited shelf space. You want to **group similar products** together — like how supermarkets place chips, drinks, or cereals in separate zones.
#
# ### 🧠 How AI helps:
#
# We use a popular AI method called **K-Means Clustering**. It:
#
# * Looks at each product’s **demand (how often people buy it)** and **size**.
# * Groups them into **zones** (like Shelf 1, Shelf 2, Shelf 3).
# * Puts **similar items together** so the warehouse is neat and fast to access.
#
# ### 📊 What we see:
#
# * A **table** showing which product goes to which shelf zone.
# * A **colorful graph** that shows how the products are grouped by the AI.
#
# 📌 This is just like how Amazon or grocery stores arrange things to **save time and space**.
#
# ---
#
# ## 📦 PART 3: Inventory Tracker (Keeping an Eye on Stock)
#
# ### 🧩 Problem:
#
# You want to know:
#
# * What's in stock?
# * What is running out?
# * Where each product is placed?
#
# ### 🧠 How AI helps:
#
# Here, we use **basic automation with Python** to:
#
# * Simulate a **small inventory** (like Sugar, Rice, Tea, etc.).
# * Let you **add or remove items** (like 10 units of sugar sold? Subtract 10!).
# * Show a clear **table of all items** — with location, quantity, and status (IN or OUT).
#
# 📌 Bonus: In Colab or Jupyter, you can even **search by product ID** with a dropdown!
#
# ---
#
# ## 🧠 Final Takeaway (Why It Matters):
#
# | What You Did          | Real-Life Example                           |
# | --------------------- | ------------------------------------------- |
# | Delivery Optimization | Riders take shortest routes                 |
# | Shelf Allocation      | Stores arrange fast-moving items together   |
# | Inventory Management  | Warehouses keep stock updated automatically |
#
# This lab shows how AI can help run **modern logistics** efficiently — just like the **systems used by Amazon, FedEx, or big grocery chains**.
#
# ---
#
# ## 💬 Want an analogy?
#
# **Imagine you’re running a pizza shop:**
#
# * You find the **quickest delivery path** for the rider (TSP Route).
# * You **organize toppings and sauces** on shelves based on how often they're used (K-Means).
# * You track if **cheese or flour is about to finish** (Inventory tracker).
#
# ➡️ Now you’re doing what this lab teaches — **AI logistics** made simple!
#
# ---

# %%
# ================================================================
# 🚚 WEEK 11 – DAY 2 LAB
# AI-Powered Warehouse Optimization & Logistics Automation
# ================================================================
# This notebook covers 3 tasks:
# 1. Route Optimization (Travelling Salesman Problem - TSP)
# 2. Shelf Space Allocation using K-Means Clustering
# 3. Simulated Inventory Tracker with Pandas
# ================================================================
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# ======================
# 📦 Import Libraries
# ======================

# Numpy: for numerical operations (distance calculations, arrays)
import numpy as np

# Pandas: for handling tabular data like products/inventory
import pandas as pd

# Matplotlib + Seaborn: for creating plots and visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# KMeans: clustering algorithm from scikit-learn
from sklearn.cluster import KMeans

# ipywidgets: for interactive search dropdowns (only works in Jupyter/Colab)
try:
    from ipywidgets import interact
except:
    pass


# ================================================================
# 🧭 PART 1: Simulated Route Optimization (TSP)
# ================================================================
print("\n" + "="*70)
print("🧭 PART 1: SIMULATED ROUTE OPTIMIZATION (Travelling Salesman Problem)")
print("="*70)

# Create dictionary of delivery locations with (x, y) coordinates
# Warehouse is starting point, Customers A–D are destinations
locations = {
    "Warehouse": (0, 0),
    "Customer A": (2, 4),
    "Customer B": (5, 2),
    "Customer C": (6, 6),
    "Customer D": (8, 3)
}

# Convert dictionary values to numpy array for easier math operations
points = np.array(list(locations.values()))

# Extract the location names (Warehouse, Customer A, etc.)
labels = list(locations.keys())

# Function: Greedy Nearest Neighbor algorithm for TSP
def tsp_greedy(points, start=0):
    n = len(points)                      # number of locations
    visited = [False] * n                # track visited locations
    route = [start]                      # start route from 'start' index
    visited[start] = True                # mark starting point visited
    total_dist = 0                       # total distance traveled

    # Loop until all locations are visited
    for _ in range(n - 1):
        last = route[-1]                 # current location index
        nearest = None                   # nearest neighbor index
        nearest_dist = float('inf')      # initialize with infinity

        # Check all other locations
        for i in range(n):
            if not visited[i]:           # if location not visited
                # Euclidean distance between current and candidate point
                dist = np.linalg.norm(points[last] - points[i])
                if dist < nearest_dist:  # update nearest if closer
                    nearest = i
                    nearest_dist = dist

        # Add nearest neighbor to route
        route.append(nearest)
        visited[nearest] = True
        total_dist += nearest_dist       # add to total distance

    # Finally, return to starting point
    total_dist += np.linalg.norm(points[route[-1]] - points[start])
    route.append(start)                  # close the loop

    return route, total_dist

# Run algorithm on our dataset
route, total_distance = tsp_greedy(points, start=0)

# Print the optimized route
print("\nOptimized Delivery Route:")
for idx in route:
    print(" →", labels[idx], end="")
print(f"\n\n📏 Total Travel Distance: {round(total_distance, 2)} units")

# Visualization of optimized path
plt.figure(figsize=(6,6))
# Draw dashed lines between connected points in route
for i in range(len(route)-1):
    p1, p2 = points[route[i]], points[route[i+1]]
    plt.plot([p1[0], p2[0]], [p1[1], p2[1]], 'b--')

# Plot locations as red dots
plt.scatter(points[:,0], points[:,1], c='red', s=100)

# Annotate each point with its label
for i, label in enumerate(labels):
    plt.text(points[i][0]+0.1, points[i][1]+0.1, label, fontsize=12)

plt.title("🧭 Optimized Delivery Route (Greedy TSP)")
plt.xlabel("X coordinate")
plt.ylabel("Y coordinate")
plt.show()


# ================================================================
# 📊 PART 2: Shelf Space Allocation using K-Means Clustering
# ================================================================
print("\n" + "="*70)
print("📊 PART 2: SHELF SPACE ALLOCATION (K-Means Clustering)")
print("="*70)

# Create a simulated dataset of products
# Features: Demand_Frequency, Size, Category_Code
data = {
    'Product': ['A','B','C','D','E','F','G','H','I','J'],
    'Demand_Frequency': [200, 50, 300, 120, 80, 400, 20, 180, 260, 95],
    'Size': [3, 2, 5, 4, 3, 6, 2, 4, 5, 3],
    'Category_Code': [1, 2, 1, 3, 2, 1, 3, 2, 1, 3]
}
df = pd.DataFrame(data)

# Print original product table
print("\n🔍 Original Product Data")
print(df.to_string(index=False))

# Select features for clustering
X = df[['Demand_Frequency', 'Size']]

# Apply K-Means clustering with 3 shelf zones
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
df['Shelf_Zone'] = kmeans.fit_predict(X)

# Print products with assigned shelf zones
print("\n📦 Products Assigned to Shelf Zones")
print(df[['Product','Demand_Frequency','Size','Shelf_Zone']].to_string(index=False))

# Visualization of clustering results
plt.figure(figsize=(8,6))
# Scatterplot: Demand vs Size, colored by Shelf_Zone
sns.scatterplot(data=df, x='Demand_Frequency', y='Size',
                hue='Shelf_Zone', palette='Set1', s=120)

# Annotate product IDs on the scatterplot
for i, row in df.iterrows():
    plt.text(row['Demand_Frequency']+5, row['Size']+0.1, row['Product'], fontsize=9)

plt.title("📊 Shelf Allocation Clusters (K-Means)")
plt.xlabel("Demand Frequency")
plt.ylabel("Product Size")
plt.legend(title="Shelf Zone")
plt.show()


# ================================================================
# 📦 PART 3: Simulated Inventory Tracker
# ================================================================
print("\n" + "="*70)
print("📦 PART 3: SIMULATED INVENTORY TRACKER")
print("="*70)

# Create inventory dataset
inventory_data = {
    "Product_ID": ["P101", "P102", "P103", "P104", "P105"],
    "Product_Name": ["Sugar", "Rice", "Oil", "Tea", "Biscuits"],
    "Location": ["Shelf A", "Shelf B", "Shelf C", "Shelf D", "Shelf A"],
    "Status": ["IN", "IN", "OUT", "IN", "IN"],
    "Quantity": [50, 30, 0, 20, 100]
}
df_inv = pd.DataFrame(inventory_data)

# Print initial inventory
print("\n📋 Current Inventory")
print(df_inv.to_string(index=False))

# Function to update stock levels
def update_stock(product_id, change, status):
    # Check if product exists in inventory
    if product_id in df_inv["Product_ID"].values:
        # Get row index
        idx = df_inv[df_inv["Product_ID"] == product_id].index[0]
        # Update quantity (+ for incoming, - for outgoing)
        df_inv.at[idx, "Quantity"] += change
        # Update status (IN/OUT)
        df_inv.at[idx, "Status"] = status
    else:
        print("❌ Product not found!")

# Simulate transactions
update_stock("P101", -10, "OUT")   # Sugar: 10 units OUT
update_stock("P102", +15, "IN")    # Rice: 15 units IN

# Print updated inventory after changes
print("\n📦 Updated Inventory After Transactions")
print(df_inv.to_string(index=False))

# Optional interactive search dropdown (works in Jupyter/Colab)
try:
    @interact(Product_ID=df_inv["Product_ID"].tolist())
    def search_inventory(Product_ID):
        display(df_inv[df_inv["Product_ID"] == Product_ID])
except:
    pass
# Out:
# ...
# 🧭 PART 1: SIMULATED ROUTE OPTIMIZATION (Travelling Salesman Problem)
# ...
#
# Optimized Delivery Route:
#  → Warehouse → Customer A → Customer B → Customer D → Customer C → Warehouse
#
# 📏 Total Travel Distance: 23.33 units
# ...
# 📊 PART 2: SHELF SPACE ALLOCATION (K-Means Clustering)
# ...
#
# 🔍 Original Product Data
# Product  Demand_Frequency  Size  Category_Code
#       A               200     3              1
#       B                50     2              2
#       C               300     5              1
#       D               120     4              3
#       E                80     3              2
#       F               400     6              1
#       G                20     2              3
#       H               180     4              2
#       I               260     5              1
#       J                95     3              3
#
# 📦 Products Assigned to Shelf Zones
# Product  Demand_Frequency  Size  Shelf_Zone
#       A               200     3           0
# ...

# %% [markdown]
# ---
#
# # **🎯 What is Streamlit?**
#
#
# ---
#
#
# ✅ **A Python-based framework** to build web apps easily.
# ✅ **Designed for data science & ML apps**.
# ✅ **Requires minimal code** (just `streamlit run script.py` to launch).
# ✅ **Live updates** – changes appear instantly.
#
# **Example Use Cases:**
# 📊 Dashboards, 📈 Data Visualizations, 🤖 Machine Learning Models, 📝 Interactive Forms.
#
# ---
#
# # **📌 Step 1: Installing Streamlit**
# Since Streamlit is **not built into Colab**, install it in your local machine:
#
# ```bash
# pip install streamlit
# ```
#
# ✅ Run the command in **your terminal (Windows, macOS, or Linux)**.
#
# > **💡 If you face issues**, try:
# > `pip install --upgrade streamlit`
#
# ---
#
# # **📌 Step 2: Running Streamlit**
# To check the installation, run:
#
# ```bash
# streamlit hello
# ```
#
# This opens a **demo Streamlit app** in your **browser**.
#
# ---
#
# # **📌 Step 3: Creating Your First Streamlit App**
# Create a **new Python file**:
#
# ```bash
# touch my_first_app.py
# ```
#
# Open it and add:
#
# ```python
# import streamlit as st
#
# st.title("🚀 My First Streamlit App")
# st.write("Hello, this is my first interactive web app with Streamlit!")
# ```
#
# Now, **run the app**:
#
# ```bash
# streamlit run my_first_app.py
# ```
#
# 🎉 Your **browser will open a web page** with the **title and text displayed**.
#
# ---
#
# # **📌 Step 4: Adding User Input**
# Streamlit allows users to **enter text, numbers, and choices**.
#
# ### **🔹 Example: Taking User Input**
# ```python
# name = st.text_input("Enter your name:")
# if name:
#     st.write(f"👋 Hello, {name}!")
# ```
#
# ✅ **`st.text_input("Label")`** → Creates a text box.
# ✅ **`st.write(f"Message {variable}")`** → Displays output dynamically.
#
# ---
#
# # **📌 Step 5: Adding Buttons & Interactivity**
# Streamlit makes buttons **super easy**.
#
# ### **🔹 Example: Button Click Event**
# ```python
# if st.button("Click Me"):
#     st.write("🎉 You clicked the button!")
# ```
#
# ✅ **`st.button("Label")`** → Creates a button.
# ✅ **Runs the `if` block when clicked**.
#
# ---
#
# # **📌 Step 6: Displaying Data (Tables & DataFrames)**
# Streamlit makes **data visualization easy**.
#
# ### **🔹 Example: Showing a Pandas DataFrame**
# ```python
# import pandas as pd
#
# data = {"Name": ["Alice", "Bob", "Charlie"], "Age": [25, 30, 35]}
# df = pd.DataFrame(data)
#
# st.write("📊 Here’s a sample dataset:")
# st.dataframe(df)
# ```
#
# ✅ **`st.dataframe(df)`** → Displays an interactive table.
#
# ---
#
# # **📌 Step 7: Adding Select Boxes (Dropdowns)**
# Users can **choose options from a dropdown**.
#
# ### **🔹 Example: Selecting an Option**
# ```python
# fruit = st.selectbox("Pick a fruit:", ["Apple", "Banana", "Cherry"])
#
# st.write(f"🍓 You selected: {fruit}")
# ```
#
# ✅ **`st.selectbox("Label", [Options])`** → Creates a dropdown.
#
# ---
#
# # **📌 Step 8: Adding Sliders**
# Sliders allow users to **select a value dynamically**.
#
# ### **🔹 Example: Slider for Age Selection**
# ```python
# age = st.slider("Select your age:", 18, 100, 25)
#
# st.write(f"🎂 Your age: {age}")
# ```
#
# ✅ **`st.slider("Label", min, max, default)`** → Creates a slider.
#
# ---
#
# # **📌 Step 9: Adding Charts**
# Streamlit supports **Matplotlib, Seaborn, and Plotly**.
#
# ### **🔹 Example: Simple Line Chart**
# ```python
# import numpy as np
# import pandas as pd
#
# # Generate sample data
# chart_data = pd.DataFrame(np.random.randn(20, 3), columns=["A", "B", "C"])
#
# # Show the chart
# st.line_chart(chart_data)
# ```
#
# ✅ **`st.line_chart(df)`** → Plots a simple **line chart**.
#
# ---
#
# # **📌 Step 10: Uploading Files**
# Users can **upload CSV files**.
#
# ### **🔹 Example: Uploading a File**
# ```python
# uploaded_file = st.file_uploader("Upload a CSV file", type=["csv"])
#
# if uploaded_file is not None:
#     df = pd.read_csv(uploaded_file)
#     st.dataframe(df)
# ```
#
# ✅ **`st.file_uploader("Label", type=["csv"])`** → Allows file uploads.
#
# ---
#
# # **📌 Step 11: Sidebar for Navigation**
# We can **move UI elements to a sidebar** for better organization.
#
# ### **🔹 Example: Adding a Sidebar**
# ```python
# st.sidebar.title("Navigation")
# page = st.sidebar.radio("Go to:", ["Home", "About"])
#
# if page == "Home":
#     st.write("🏠 Welcome to the Home Page")
# elif page == "About":
#     st.write("ℹ️ This is an About Page")
# ```
#
# ✅ **`st.sidebar.radio()`** → Adds a **navigation menu**.
#
# ---
#
# # **📌 Step 12: Caching for Performance**
# Streamlit can **cache expensive computations** to make apps faster.
#
# ### **🔹 Example: Using Caching**
# ```python
# @st.cache_data
# def expensive_function():
#     import time
#     time.sleep(3)  # Simulating delay
#     return "✅ Data Loaded!"
#
# st.write(expensive_function())  # Runs fast after first execution
# ```
#
# ✅ **`@st.cache_data`** → **Stores results**, so they don’t re-run.
#
# ---
#
# # **📌 Step 13: Running the Final App**
# Once your app is complete, **run it with**:
#
# ```bash
# streamlit run my_first_app.py
# ```
#
# ---
#
# # **📌 Summary of Key Features**
# | Feature            | Streamlit Function |
# |--------------------|-------------------|
# | Title & Text      | `st.title()`, `st.write()` |
# | User Input        | `st.text_input()`, `st.button()` |
# | Dropdown          | `st.selectbox()` |
# | Sliders          | `st.slider()` |
# | Tables           | `st.dataframe()` |
# | Charts           | `st.line_chart()`, `st.bar_chart()` |
# | File Upload      | `st.file_uploader()` |
# | Sidebar          | `st.sidebar.radio()` |
# | Caching          | `@st.cache_data` |
#
#
# ---
#
# # **🎉 Congratulations!**
# You’ve now **mastered Streamlit basics** and are ready to build **amazing interactive web apps**. 🚀

# %% [markdown]
# ---
#
# # 📦 Streamlit Tutorial: AI-Powered Warehouse Optimization App
#
# This tutorial walks you through building an interactive warehouse optimization dashboard using Streamlit. It includes **route optimization (TSP)**, **shelf allocation (K-Means)**, and an **inventory tracker** - all in one clean interface.
#
# ---
#
# ## ✅ 1️⃣ Introduction
#
# ### 🔍 Overview of Warehouse Automation
#
# Warehouses today deal with hundreds or thousands of items and delivery routes. AI can help in:
#
# * Optimizing delivery paths
# * Assigning shelf space efficiently
# * Tracking stock levels in real-time
#
# This app simulates those tasks using simple, easy-to-understand algorithms and visualizations.
#
# ---
#
# ### ⚙️ What the App Will Do
#
# | Module                 | Description                                                         |
# | ---------------------- | ------------------------------------------------------------------- |
# | **Route Optimization** | Solves a delivery route using the Travelling Salesman Problem (TSP) |
# | **Shelf Allocation**   | Uses K-Means clustering to decide where products should go          |
# | **Inventory Tracker**  | Keeps track of stock levels using a table and search tool           |
#
# You’ll learn how to:
#
# * Upload CSVs
# * Build visualizations
# * Add interactivity with Streamlit widgets
#
# ---
#
# ## 🛠️ 2️⃣ Setting Up Your Environment
#
# ### 🔧 Install Required Libraries
#
# Open your terminal or Colab cell and install the libraries below:
#
# ```bash
# pip install streamlit pandas matplotlib seaborn scikit-learn
# ```
#
# > Optional for interactive search (used later):
#
# ```bash
# pip install ipywidgets
# ```
#
# ---
#
# ### 📁 Create a New Python File
#
# Make a file named `app.py` in your working directory:
#
# ```bash
# touch app.py
# ```
#
# Or in Colab or Jupyter, just copy the content in a new cell and run using `streamlit run app.py`.
#
# ---
#
# ## 🧱 3️⃣ Streamlit App Structure
#
# Here’s the **starter code** to set up the layout of your Streamlit app with proper comments.
#
# ---
#
# ### ✅ Working Code for App Skeleton
#
# ```python
# # 📦 Streamlit App: AI-Powered Warehouse Optimization
#
# import streamlit as st
#
# # =======================
# # Page Settings
# # =======================
# st.set_page_config(
#     page_title="Warehouse AI Optimizer",
#     layout="centered",
#     page_icon="📦"
# )
#
# # =======================
# # App Title and Header
# # =======================
# st.title("📦 AI-Powered Warehouse Optimization App")
# st.markdown("""
# Welcome to your warehouse assistant powered by AI!
# This app will help you:
# - 🧭 Optimize delivery routes
# - 📊 Allocate shelf space smartly
# - 📦 Track inventory stock levels
# """)
#
# # =======================
# # Navigation Tabs
# # =======================
# tab = st.sidebar.radio("Select Module", ["Home 🏠", "Route Optimization 🧭", "Shelf Allocation 📊", "Inventory Tracker 📦"])
#
# # Placeholder Message
# if tab == "Home 🏠":
#     st.subheader("🔍 What This App Does")
#     st.markdown("""
# This app demonstrates how AI can be used to improve warehouse and logistics operations:
# - **Route Optimization (TSP)**: Efficient delivery paths
# - **Shelf Allocation (KMeans)**: Grouping items smartly
# - **Inventory Tracker**: Managing in/out stock
# Use the left sidebar to navigate to each module and explore!
# """)
# ```
#
# ---
#
# ### 🧠 Explanation of Each Section
#
# | Code Block                | Purpose                                               |
# | ------------------------- | ----------------------------------------------------- |
# | `st.set_page_config(...)` | Sets the title, layout, and icon for your web app     |
# | `st.title(...)`           | Displays the main heading                             |
# | `st.markdown(...)`        | Adds formatted introduction text                      |
# | `st.sidebar.radio(...)`   | Provides a sidebar tab menu for switching views       |
# | `if tab == ...`           | Renders different content depending on user selection |
#
# ---

# %% [markdown]
# ---
#
# ## 🚚 **4️⃣ Route Optimization (Travelling Salesman Problem)**
#
# This module simulates how a delivery van visits multiple customer locations with **minimum travel distance**. We'll use a simple greedy algorithm to solve the **TSP** (Travelling Salesman Problem).
#
# ---
#
# ### 🧾 📄 Step-by-Step User Flow
#
# 1. App displays sample map (Warehouse + Customers A–D).
# 2. User can **see the optimized delivery route**.
# 3. Visualizes the route path (as a line plot).
# 4. **Later** (optional): User can **upload custom locations**.
#
# ---
#
# ### ✅ Full Working Code (Add under `if tab == "Route Optimization 🧭":`)
#
# ```python
# import numpy as np                       # For numerical operations (like distance)
# import matplotlib.pyplot as plt          # For route visualization
#
# if tab == "Route Optimization 🧭":
#     st.subheader("🧭 Delivery Route Optimizer")  # Section heading
#
#     # ---------------------------------------------
#     # Step 1: Define default delivery coordinates
#     # ---------------------------------------------
#     st.markdown("#### 📍 Default Delivery Points")
#     st.info("Warehouse and 4 Customer locations")
#
#     # Dictionary with names and (x, y) coordinates
#     locations = {
#         "Warehouse": (0, 0),
#         "Customer A": (2, 4),
#         "Customer B": (5, 2),
#         "Customer C": (6, 6),
#         "Customer D": (8, 3)
#     }
#
#     # Convert location values to NumPy array for easier math
#     points = np.array(list(locations.values()))
#
#     # Extract the names (for labeling route)
#     labels = list(locations.keys())
#
#     # ---------------------------------------------
#     # Step 2: Define the TSP Greedy Algorithm
#     # ---------------------------------------------
#     def tsp_greedy(points, start=0):
#         n = len(points)                      # Total number of locations
#         visited = [False] * n                # Track which locations are visited
#         route = [start]                      # Start from 'Warehouse'
#         visited[start] = True                # Mark it as visited
#         total_dist = 0                       # To store total distance
#
#         # Loop through all other locations
#         for _ in range(n - 1):
#             last = route[-1]                 # Last visited location index
#             nearest = None                   # Will store the nearest neighbor index
#             nearest_dist = float('inf')      # Set initial distance to infinity
#
#             # Check all other unvisited locations
#             for i in range(n):
#                 if not visited[i]:           # Skip if already visited
#                     # Euclidean distance from last location to current one
#                     dist = np.linalg.norm(points[last] - points[i])
#                     if dist < nearest_dist:  # If it's the closest so far
#                         nearest = i
#                         nearest_dist = dist
#
#             # Add the nearest neighbor to the route
#             route.append(nearest)
#             visited[nearest] = True
#             total_dist += nearest_dist       # Add distance to total
#
#         # Return to starting point (Warehouse)
#         total_dist += np.linalg.norm(points[route[-1]] - points[start])
#         route.append(start)                  # Close the route
#
#         return route, total_dist             # Return final route and distance
#
#     # ---------------------------------------------
#     # Step 3: Call the algorithm and show route
#     # ---------------------------------------------
#     route, total_distance = tsp_greedy(points)
#
#     # Show route as text
#     st.markdown("#### 🗺️ Optimized Route")
#     route_str = " → ".join([labels[i] for i in route])  # Convert indices to names
#     st.success(f"**Optimized Route:** {route_str}")     # Display route
#     st.info(f"📏 Total Travel Distance: {round(total_distance, 2)} units")  # Show distance
#
#     # ---------------------------------------------
#     # Step 4: Visualize the route with Matplotlib
#     # ---------------------------------------------
#     fig, ax = plt.subplots()                  # Create a figure and axis
#
#     # Draw lines between each connected point in the route
#     for i in range(len(route) - 1):
#         p1, p2 = points[route[i]], points[route[i + 1]]   # Consecutive points
#         ax.plot([p1[0], p2[0]], [p1[1], p2[1]], 'b--')     # Dashed blue line
#
#     # Plot the delivery locations
#     ax.scatter(points[:, 0], points[:, 1], c='red', s=100)  # Red dots for locations
#
#     # Add labels (Warehouse, Customer A, etc.)
#     for i, label in enumerate(labels):
#         ax.text(points[i][0] + 0.1, points[i][1] + 0.1, label, fontsize=10)
#
#     # Add chart title and axes labels
#     ax.set_title("🧭 Optimized Delivery Route (TSP)")
#     ax.set_xlabel("X Coordinate")
#     ax.set_ylabel("Y Coordinate")
#
#     # Show plot in Streamlit
#     st.pyplot(fig)
#
# ```
#
# ---
#
# ### 🧠 Explanation of Each Step (for Students)
#
# | Section                          | Purpose                                                      |
# | -------------------------------- | ------------------------------------------------------------ |
# | **locations dictionary**         | Stores fixed coordinates of warehouse and customers          |
# | **`tsp_greedy()` function**      | Simple logic to find nearest unvisited neighbor at each step |
# | **`route` and `total_distance`** | Outputs optimized delivery path and total cost               |
# | **Matplotlib plot**              | Visually shows the complete route on a 2D map                |
#
# ---
#
# ### 🧪 Sample Output (Visual)
#
# ✅ Text output:
# `Warehouse → Customer A → Customer C → Customer D → Customer B → Warehouse`
# ✅ Graph output:
# A 2D line plot with labeled points and connecting dashed blue lines.
#
# ---

# %% [markdown]
# ---
#
# ## 🗂️ Section 5️⃣ - Shelf Space Allocation using Clustering
#
# 📌 **Objective**: Help students simulate how a warehouse can group products by characteristics like **demand** and **size** to optimize shelf usage using **K-Means Clustering**.
#
# ---
#
# ### ✅ Paste this inside:
#
# ```python
# elif tab == "Shelf Allocation 📊":
# ```
#
# ---
#
# ### 🧠 Code with Comments
#
# ```python
# import pandas as pd              # For data handling
# from sklearn.cluster import KMeans  # Clustering algorithm
# import seaborn as sns            # For colorful plots
# import matplotlib.pyplot as plt  # For visualizing clusters
#
# st.subheader("📊 Shelf Space Allocation with K-Means Clustering")
#
# # -------------------------------------
# # Step 1: Simulated Product Dataset
# # -------------------------------------
# st.markdown("#### 🧺 Product Dataset")
#
# # Create a small dataset of 10 products with demand, size, and category
# data = {
#     'Product': ['A','B','C','D','E','F','G','H','I','J'],
#     'Demand_Frequency': [200, 50, 300, 120, 80, 400, 20, 180, 260, 95],
#     'Size': [3, 2, 5, 4, 3, 6, 2, 4, 5, 3],
#     'Category_Code': [1, 2, 1, 3, 2, 1, 3, 2, 1, 3]
# }
#
# # Convert to Pandas DataFrame
# df = pd.DataFrame(data)
#
# # Show original table to user
# st.dataframe(df)
#
# # -------------------------------------
# # Step 2: K-Means Clustering
# # -------------------------------------
# st.markdown("#### 📦 Assigning Shelf Zones using K-Means")
#
# # Let user pick how many zones (clusters) to create
# num_clusters = st.slider("🔢 Select number of shelf zones", 2, 5, 3)
#
# # Use only demand and size for clustering
# X = df[['Demand_Frequency', 'Size']]
#
# # Fit K-Means model
# kmeans = KMeans(n_clusters=num_clusters, random_state=42, n_init=10)
# df['Shelf_Zone'] = kmeans.fit_predict(X)
#
# # Show new DataFrame with zones assigned
# st.success("✅ Shelf zones assigned using clustering:")
# st.dataframe(df[['Product','Demand_Frequency','Size','Shelf_Zone']])
#
# # -------------------------------------
# # Step 3: Visualize Clusters
# # -------------------------------------
# st.markdown("#### 🎯 Cluster Visualization")
#
# # Set up figure
# fig2, ax2 = plt.subplots(figsize=(8, 6))
#
# # Plot each product as a point colored by shelf zone
# sns.scatterplot(data=df, x='Demand_Frequency', y='Size',
#                 hue='Shelf_Zone', palette='Set1', s=100, ax=ax2)
#
# # Label each point with product name
# for i, row in df.iterrows():
#     ax2.text(row['Demand_Frequency']+2, row['Size']+0.1, row['Product'], fontsize=9)
#
# # Set labels and title
# ax2.set_title("📊 Shelf Allocation Zones (K-Means)")
# ax2.set_xlabel("Demand Frequency")
# ax2.set_ylabel("Product Size")
#
# # Show plot
# st.pyplot(fig2)
# ```
#
# ---
#
# ### 📚 Layman-Friendly Explanation
#
# | Step | Concept            | Explanation                                                  |
# | ---- | ------------------ | ------------------------------------------------------------ |
# | 1️⃣  | Product Dataset    | Products have different demand and sizes                     |
# | 2️⃣  | K-Means Clustering | Groups products into shelf zones based on similarity         |
# | 3️⃣  | Clusters           | Same cluster → products stored near each other               |
# | 4️⃣  | Slider             | Lets user experiment with 2 to 5 shelf zones                 |
# | 5️⃣  | Visualization      | See how products are grouped visually using color-coded dots |
#
# ---
#
# ### 🧪 What students understand from this section:
#
# * How warehouse software can use **AI to group products**
# * What clustering is, and why it's useful in logistics
# * How **Streamlit** + **Scikit-learn** + **Seaborn** work together
#
# ---

# %% [markdown]
# ---
#
# ## 🗂️ Section 6️⃣ – Inventory Tracker with Transactions
#
# 📌 **Objective**: Simulate a basic inventory management system where students can **view**, **update**, and **track stock levels** — just like in real warehouses.
#
# ---
#
# ### ✅ Paste this inside:
#
# ```python
# elif tab == "Inventory Tracker 📦":
# ```
#
# ---
#
# ### 🧠 Complete Code with Comments
#
# ```python
# import pandas as pd  # For table management
# import streamlit as st  # For frontend
# import plotly.express as px  # For optional bar chart visualizations
#
# st.subheader("📦 Simulated Inventory Tracker")
#
# # -----------------------------------------
# # Step 1: Create Initial Inventory Dataset
# # -----------------------------------------
#
# # A simple inventory dataset for a few products
# inventory_data = {
#     "Product_ID": ["P101", "P102", "P103", "P104", "P105"],
#     "Product_Name": ["Sugar", "Rice", "Oil", "Tea", "Biscuits"],
#     "Location": ["Shelf A", "Shelf B", "Shelf C", "Shelf D", "Shelf A"],
#     "Status": ["IN", "IN", "OUT", "IN", "IN"],
#     "Quantity": [50, 30, 0, 20, 100]
# }
#
# # Create a DataFrame from the dictionary
# df_inv = pd.DataFrame(inventory_data)
#
# # -----------------------------------------
# # Step 2: Show Inventory Table
# # -----------------------------------------
#
# st.markdown("#### 📋 Current Inventory")
# # Display the table of inventory products
# st.dataframe(df_inv)
#
# # -----------------------------------------
# # Step 3: Stock Update Inputs (User Form)
# # -----------------------------------------
#
# st.markdown("#### 🔁 Update Inventory")
#
# # Create a form so users can enter product ID and stock changes
# with st.form("inventory_form"):
#     product_id = st.selectbox("Select Product ID", df_inv["Product_ID"])
#     change = st.number_input("Enter quantity change (+/-)", step=1, value=0)
#     status = st.selectbox("Select new status", ["IN", "OUT"])
#     submit_button = st.form_submit_button("Update Stock")
#
#     # If form submitted
#     if submit_button:
#         # Check if product exists in DataFrame
#         if product_id in df_inv["Product_ID"].values:
#             # Find the row index
#             idx = df_inv[df_inv["Product_ID"] == product_id].index[0]
#             # Update the Quantity value
#             df_inv.at[idx, "Quantity"] += change
#             # Update the Status
#             df_inv.at[idx, "Status"] = status
#             st.success(f"✅ Inventory updated for {product_id}")
#         else:
#             st.error("❌ Product not found!")
#
# # -----------------------------------------
# # Step 4: Show Updated Inventory Table
# # -----------------------------------------
#
# st.markdown("#### 📦 Updated Inventory")
# st.dataframe(df_inv)
#
# # -----------------------------------------
# # Step 5: Optional Visualization
# # -----------------------------------------
#
# st.markdown("#### 📊 Stock Levels Chart (Optional)")
#
# # Create a bar chart to show updated stock visually
# fig = px.bar(df_inv, x="Product_Name", y="Quantity",
#              color="Status", text="Quantity",
#              title="Inventory Levels by Product",
#              labels={"Quantity": "Units in Stock"},
#              height=400)
# st.plotly_chart(fig)
# ```
#
# ---
#
# ### 🧠 Layman Explanation (What Students Learn)
#
# | Step | What Happens    | Explanation                                                         |
# | ---- | --------------- | ------------------------------------------------------------------- |
# | 1️⃣  | Inventory Table | We load a simple warehouse stock table into the app                 |
# | 2️⃣  | View Data       | Students see product names, stock levels, and status                |
# | 3️⃣  | Update Stock    | Students simulate adding/removing units from inventory              |
# | 4️⃣  | Live Update     | They instantly see changes reflected in the table                   |
# | 5️⃣  | Chart           | Easy-to-understand bar graph shows which items are low/out of stock |
#
# ---
#
# ### 💡 Features to Highlight
#
# * Uses **Streamlit forms** for real-time interaction.
# * Uses **Plotly** for an optional chart showing stock levels.
# * Reinforces understanding of **data updates** in real time.
#
# ---

# %% [markdown]
# This all-in-one Streamlit app covers:
#
# 1. 📍 **Route Optimization (TSP)**
# 2. 📊 **Shelf Space Clustering (K-Means)**
# 3. 📦 **Inventory Tracker with Transactions**
# 4. 📁 **CSV Upload for Inventory**
# 5. 🖼️ **Visualizations**
# 6. ✅ **Clean layout with sidebar navigation**
#
# ---
#
# ## ✅ Final Code — `warehouse_app.py`

# %%
pip install streamlit pandas matplotlib seaborn scikit-learn plotly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 53.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 75.7 MB/s eta 0:00:00
# ...

# %%
# ================================================================
# 🚚 AI-Powered Warehouse Optimization App (Streamlit)
# ================================================================
# 📍 Route Optimization (Travelling Salesman Problem)
# 📊 Shelf Space Allocation (K-Means Clustering)
# 📦 Inventory Management with Transactions
# 📁 CSV Upload Support
# ================================================================

import streamlit as st
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.cluster import KMeans

# Set Streamlit page configuration
st.set_page_config(page_title="Warehouse AI Optimizer", layout="centered")

# Sidebar for navigation
st.sidebar.title("🧭 Warehouse AI App")
tab = st.sidebar.radio("Go to", ["🏠 Home", "🧭 Route Optimizer", "📊 Shelf Clustering", "📦 Inventory Tracker"])

# ---------------------------------------------
# 🏠 HOME
# ---------------------------------------------
if tab == "🏠 Home":
    st.title("🚚 AI-Powered Warehouse Optimization")
    st.markdown("""
    This interactive app demonstrates how AI can optimize:
    - **Delivery Routes** (TSP)
    - **Shelf Space Allocation** (K-Means Clustering)
    - **Inventory Tracking** (Real-time updates)

    Built with **Python**, **Pandas**, **Scikit-learn**, **Matplotlib**, and **Streamlit**.
    """)

# ---------------------------------------------
# 🧭 ROUTE OPTIMIZER (Travelling Salesman Problem)
# ---------------------------------------------
elif tab == "🧭 Route Optimizer":
    st.title("🧭 Route Optimizer – TSP")

    # Coordinates for warehouse and customers
    locations = {
        "Warehouse": (0, 0),
        "Customer A": (2, 4),
        "Customer B": (5, 2),
        "Customer C": (6, 6),
        "Customer D": (8, 3)
    }

    # Extract coordinates and labels
    points = np.array(list(locations.values()))
    labels = list(locations.keys())

    # TSP algorithm (Greedy Nearest Neighbor)
    def tsp_greedy(points, start=0):
        n = len(points)
        visited = [False] * n
        route = [start]
        visited[start] = True
        total_dist = 0
        for _ in range(n - 1):
            last = route[-1]
            nearest = None
            nearest_dist = float('inf')
            for i in range(n):
                if not visited[i]:
                    dist = np.linalg.norm(points[last] - points[i])
                    if dist < nearest_dist:
                        nearest = i
                        nearest_dist = dist
            route.append(nearest)
            visited[nearest] = True
            total_dist += nearest_dist
        total_dist += np.linalg.norm(points[route[-1]] - points[start])
        route.append(start)
        return route, total_dist

    route, total_distance = tsp_greedy(points)

    # Show Route
    st.subheader("🚚 Optimized Route")
    for idx in route:
        st.write("➡️", labels[idx])

    st.write(f"📏 **Total Distance:** `{round(total_distance, 2)} units`")

    # Visualize Route
    st.subheader("📍 Route Map")
    fig, ax = plt.subplots(figsize=(6, 6))
    for i in range(len(route) - 1):
        p1, p2 = points[route[i]], points[route[i+1]]
        ax.plot([p1[0], p2[0]], [p1[1], p2[1]], 'b--')
    ax.scatter(points[:, 0], points[:, 1], c='red', s=100)
    for i, label in enumerate(labels):
        ax.text(points[i][0]+0.1, points[i][1]+0.1, label, fontsize=12)
    ax.set_xlabel("X")
    ax.set_ylabel("Y")
    ax.set_title("Optimized Delivery Route")
    st.pyplot(fig)

# ---------------------------------------------
# 📊 SHELF CLUSTERING (K-Means)
# ---------------------------------------------
elif tab == "📊 Shelf Clustering":
    st.title("📊 Shelf Space Allocation – K-Means")

    # Sample product data
    data = {
        'Product': ['A','B','C','D','E','F','G','H','I','J'],
        'Demand_Frequency': [200, 50, 300, 120, 80, 400, 20, 180, 260, 95],
        'Size': [3, 2, 5, 4, 3, 6, 2, 4, 5, 3],
    }
    df = pd.DataFrame(data)

    st.subheader("📋 Product Table")
    st.dataframe(df)

    # Clustering
    X = df[['Demand_Frequency', 'Size']]
    kmeans = KMeans(n_clusters=3, n_init=10, random_state=42)
    df['Shelf_Zone'] = kmeans.fit_predict(X)

    st.subheader("📦 Shelf Zones")
    st.dataframe(df)

    # Plot
    fig2 = px.scatter(df, x='Demand_Frequency', y='Size',
                      color='Shelf_Zone', text='Product',
                      title="Shelf Allocation (K-Means)",
                      color_continuous_scale='Portland')
    st.plotly_chart(fig2)

# ---------------------------------------------
# 📦 INVENTORY TRACKER (with CSV Upload)
# ---------------------------------------------
elif tab == "📦 Inventory Tracker":
    st.title("📦 Inventory Tracker")

    st.markdown("#### 📁 Upload Inventory CSV (Optional)")
    uploaded_file = st.file_uploader("Choose CSV file", type="csv")

    if uploaded_file is not None:
        df_inv = pd.read_csv(uploaded_file)
    else:
        df_inv = pd.DataFrame({
            "Product_ID": ["P101", "P102", "P103", "P104", "P105"],
            "Product_Name": ["Sugar", "Rice", "Oil", "Tea", "Biscuits"],
            "Location": ["Shelf A", "Shelf B", "Shelf C", "Shelf D", "Shelf A"],
            "Status": ["IN", "IN", "OUT", "IN", "IN"],
            "Quantity": [50, 30, 0, 20, 100]
        })

    st.markdown("#### 📋 Current Inventory")
    st.dataframe(df_inv)

    st.markdown("#### 🔁 Update Stock")

    with st.form("stock_form"):
        product_id = st.selectbox("Select Product", df_inv["Product_ID"])
        change = st.number_input("Quantity Change (+/-)", value=0, step=1)
        status = st.selectbox("Status", ["IN", "OUT"])
        update = st.form_submit_button("Apply Update")

        if update:
            idx = df_inv[df_inv["Product_ID"] == product_id].index[0]
            df_inv.at[idx, "Quantity"] += change
            df_inv.at[idx, "Status"] = status
            st.success(f"✅ Updated stock for {product_id}")

    st.markdown("#### 📦 Updated Inventory")
    st.dataframe(df_inv)

    st.markdown("#### 📊 Inventory Bar Chart")
    fig3 = px.bar(df_inv, x="Product_Name", y="Quantity", color="Status",
                  title="Stock Level per Product", text="Quantity")
    st.plotly_chart(fig3)
# Out:
# 2025-09-25 05:03:02.142 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-25 05:03:02.143 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-25 05:03:02.356
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2025-09-25 05:03:02.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-25 05:03:02.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-25 05:03:02.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %% [markdown]
# ---
#
# ## ✅ How to Deploy on Streamlit
#
# 1. **Install requirements:**
#
#    ```bash
#    pip install streamlit pandas matplotlib seaborn scikit-learn plotly
#    ```
#
# 2. **Save as:**
#    `warehouse_app.py`
#
# 3. **Run locally:**
#
#    ```bash
#    streamlit run warehouse_app.py
#    ```
#
# 4. **Deploy to [Streamlit Cloud](https://share.streamlit.io/):**
#
#    * Upload your file to a public GitHub repo.
#    * Go to [https://share.streamlit.io/](https://share.streamlit.io/)
#    * Connect GitHub → Select repo → Set main file to `warehouse_app.py`
#
# ---
#
# ## 🧠 Summary
#
# This app demonstrates:
#
# * Real-life **logistics problems** solved using AI (TSP, KMeans)
# * Easy-to-use **Streamlit interface**
# * Uploadable **CSV-based inventory system**
# * Visual analytics for **decision making**
